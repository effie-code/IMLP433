# %% [markdown]
# ## 基礎題 - 算出斜率w與截距b
#
# y = wx + b
#
# 記得計算前X須符合資料格式
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# 設定 NumPy 的輸出格式，避免科學計數法
np.set_printoptions(suppress=True, precision=10)

# %%
x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#將模型工具指派給一變數做使用
#注意轉換x得格式1D->2D
#將x,y資料導入LinearRegression演算法做訓練
#列印出訓練完成之函數的斜率與截距

# %%
#先看一下xy長相
#畫圖
plt.scatter(x,y,c='b')
plt.show()

# %%
#由sklearn.linear_model的套件裡,import "LinearRegression" 這個套件
from sklearn.linear_model import LinearRegression
#將LinearRegression()指派給regr
regr = LinearRegression()
regr
# Out:
# LinearRegression()

# %%
#將一維資料轉成二維資料
print(x.shape)
#reshape x將它從一維變成二維
X = x.reshape(-1,1)
print(X.shape)
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
#X是被我Reshape過的x, y是原本的y
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
#X是被我Reshape過的x, y是原本的y, Y是用Reshape過的2D X xpredict出來的
print(Y)
# Out:
# [ 0.2731296895  0.6031334651  0.9331372568  1.2631410323  1.5931448079
#   1.9231485835  2.2531523752  2.5831561507  2.9131599263  3.2431637019
#   3.5731674936  3.9031712692  4.2331750447  4.5631788203  4.893182612
#   5.2231863876  5.5531901631  5.8831939549  6.2131977304  6.543201506
#   6.8732052815  7.2032090733  7.5332128488  7.8632166244  8.1932203999
#   8.5232241917  8.8532279672  9.1832317428  9.5132355183  9.8432393101
#  10.1732430856 10.5032468612 10.8332506367 11.1632544285 11.493258204
#  11.8232619796 12.1532657713 12.4832695469 12.8132733224 13.143277098
#  13.4732808897 13.8032846653 14.1332884409 14.4632922164 14.7932960081
#  15.1232997837 15.4533035593 15.7833073348 16.1133111265 16.4433149021]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y,c='g') #原本的xy
plt.plot(x, Y,c='r') #用原本的x預測出來的Y
plt.show()
#calculate mse
mse = np.sum((Y-y)**2) / len(y)# Y預測出來的  y原始的
print(mse)
# Out:
# 0.2626760696948909

# %%
#Y=WX+b
W=regr.coef_#斜率 記得要打底線_
W
#斜率=1.6170185213
# Out:
# array([1.6170185213])

# %%
b=regr.intercept_ #截距記得要打底線_
b
#截距=0.2731296894942137
# Out:
# 0.2731296894942137

# %%
Y
# Out:
# array([ 0.2731296895,  0.6031334651,  0.9331372568,  1.2631410323,
#         1.5931448079,  1.9231485835,  2.2531523752,  2.5831561507,
#         2.9131599263,  3.2431637019,  3.5731674936,  3.9031712692,
#         4.2331750447,  4.5631788203,  4.893182612 ,  5.2231863876,
#         5.5531901631,  5.8831939549,  6.2131977304,  6.543201506 ,
#         6.8732052815,  7.2032090733,  7.5332128488,  7.8632166244,
#         8.1932203999,  8.5232241917,  8.8532279672,  9.1832317428,
#         9.5132355183,  9.8432393101, 10.1732430856, 10.5032468612,
#        10.8332506367, 11.1632544285, 11.493258204 , 11.8232619796,
#        12.1532657713, 12.4832695469, 12.8132733224, 13.143277098 ,
#        13.4732808897, 13.8032846653, 14.1332884409, 14.4632922164,
#        14.7932960081, 15.1232997837, 15.4533035593, 15.7833073348,
#        16.1133111265, 16.4433149021])

# %%
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.2626760696948909

# %% [markdown]
# ## 進階題 - 切割資料集分別做訓練與預測(訓練資料80%、測試資料20%)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True, precision=10)
x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#匯入在sklearn.model_selection套件裡面的train_test_split模組
#切割數據集(訓練資料80%、測試資料20%，設定random_state=20)
#畫出訓練資料集的matplotlib圖形m

# %%
from sklearn.model_selection import train_test_split  # 確保匯入 train_test_split

# %% [markdown]
# ## 用訓練資料來 fit 函數
# 1. 只用訓練資料集的資料進行linear regression演算法<br>
# 2. 並計算出訓練階段的MSE
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_train.PNG)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)

# %%
# 檢查一下~50*0.8 train data只會有40筆
print(x_train)
print(y_train)
plt.scatter(x_train, y_train)
plt.show()
# Out:
# [ 8.16326531  3.46938776  3.67346939  0.          5.51020408  6.73469388
#   7.34693878  8.57142857  2.04081633  0.6122449   8.36734694  2.65306122
#   9.3877551   0.40816327  7.75510204  7.95918367  1.02040816  8.7755102
#   7.55102041  6.12244898  1.2244898   5.91836735  3.26530612  3.87755102
#  10.          8.97959184  4.28571429  6.53061224  6.93877551  1.42857143
#   4.48979592  2.24489796  4.08163265  1.83673469  9.79591837  5.71428571
#   6.32653061  3.06122449  5.30612245  7.14285714]
# [13.93938726  5.44529881  7.22571332  0.85848224  9.56018295 11.38956185
#  11.58403954 13.69551472  4.08573636  0.53554778 13.31678277  4.8852381
#  15.19213921  1.42771901 13.88486667 13.35550112  1.81330509 14.76548676
#  11.60186428  9.56401824  1.88362644  9.26517614  6.05133235  6.79423911
#  16.41258817 14.81731598  7.00413058 11.56755942 11.83586027  2.23557653
#   7.98149596  3.82529502  7.05424438  3.41174583 15.97997265  9.30035956
# ...

# %%
#用訓練資料來 fit 函數
regr = LinearRegression()
X_train = x_train.reshape(-1,1)#1D轉2D
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.6065922734]
# interception:  0.36802581786862376

# %%
plt.scatter(x_train, y_train, color='b')
plt.plot(x_train, Y_train, color='r')
plt.show()

# %% [markdown]
# ## 將訓練出來的函數預測測試集的X值
# 1. 使用剛剛訓練出來的模型進行測試資料集的資料預測*注意reshape<br>
# 使用X = 2.44897959，預測出來數值應該為 4.3025375<br>
# 所有測試集資料
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
1.60659227*2.44897959+ 0.36802581786862376
# Out:
# 4.302537496550393

# %% [markdown]
# 2. 並計算出測試階段的MSE

# %%
Y_train = regr.predict(X_train) 
#X是被我Reshape過的x, y是原本的y, Y是用Reshape過的2D X predict出來的

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.2284495300761316

# %%
#test with test data
#用train data求出 beta和intercep後套用到test dataset
#Y=WX+b
X_test = x_test.reshape(-1,1)
W=regr.coef_
b=regr.intercept_
Y_test = regr.predict(X_test)

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
#mse of test data =0.41, mse of trained dara=0.22, 這樣的差距是否合理????
# Out:
# 0.41344072565862955

# %%
#mse要用test的mse (在式子中用',mse:')
#為何是0.2
title='f(x)=1.6x+0.2'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,c='blue',alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='red', alpha=0.8,label='Predict')
plt.legend()
plt.show()

# %% [markdown]
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_test.PNG)
